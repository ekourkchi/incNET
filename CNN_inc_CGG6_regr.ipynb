# %% [markdown]
# <a href="https://colab.research.google.com/github/ekourkchi/incNET-data/blob/master/CNN_inc_CGG6_regr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os
import subprocess
from math import *
import numpy as np
from datetime import *
from pylab import *
import matplotlib as mpl
from matplotlib.widgets import Slider, Button, RadioButtons
import matplotlib.pyplot as plt
from astropy.table import Table, Column 
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.patches as patches
import scipy.misc as scimisc
import random

# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Loading the data

# %%
data = np.load('/content/drive/My Drive/data_64x64.npz')
images_ = data['images']
labels_ = data['labels'] 
data.close()

# %% [markdown]
# ## Looking at an example image

# %%
i = 750
print labels_[1][i]
plt.imshow(images_[i])
# Out:
# 51

# %% [markdown]
# ## Data Preparation

# %%
# print images_.shape
ix, = np.where(labels_[1]>45)

images_c = images_[ix]
labels_c = labels_[1][ix]
pgcIDs_c = labels_[0][ix]

print "data shape: ", images_c.shape
# Out:
# data shape:  (44168, 64, 64, 3)

# %%
## Shuffling  the sample to generate a fair sample
def shuffle(array, seed=0):
        random.seed(seed)
        random.shuffle(array)
        return array

# %%
n = len(labels_c)

indices = np.arange(n)
indices = shuffle(indices, seed=0)


images_cc = images_c[indices]
labels_cc = labels_c[indices]
pgcIDs_cc = pgcIDs_c[indices]

#################

indices = np.arange(1000)
images_test  = images_cc[indices]
lables_test  = labels_cc[indices]
pgcIDs_test  = pgcIDs_cc[indices]

################# 

indices = np.arange(1000, n)
images_train = images_cc[indices]
lables_train = labels_cc[indices]
pgcIDs_train = pgcIDs_cc[indices]


ibx = np.logical_not(np.isin(pgcIDs_train, pgcIDs_test))
images_train = images_train[ibx]
lables_train = lables_train[ibx]
pgcIDs_train = pgcIDs_train[ibx]

#################
# Taking only unique galxies in the test set
# This is the brute-force approach.
# I need to make this better in the future

unique_IDs = []
unique_inx = []

for i, id in enumerate(pgcIDs_test):
    if not id in unique_IDs:
        unique_IDs.append(id)
        unique_inx.append(i)
        
        
images_test  = images_test[unique_inx]
lables_test  = lables_test[unique_inx]
pgcIDs_test  = pgcIDs_test[unique_inx]

# %%
print images_train.shape , lables_train.shape
print images_test.shape , lables_test.shape
# Out:
# (40316, 64, 64, 3) (40316,)
# (963, 64, 64, 3) (963,)

# %%
plt.hist(lables_train, histtype='step', label='train', density=True)
plt.hist(lables_test, histtype='step', label='test', density=True)
# Out:
# (array([0.00637213, 0.01746436, 0.0191164 , 0.01416029, 0.01227226,
#         0.02855659, 0.02525253, 0.03256868, 0.02572454, 0.04578495]),
#  array([46. , 50.4, 54.8, 59.2, 63.6, 68. , 72.4, 76.8, 81.2, 85.6, 90. ]),
#  <a list of 1 Patch objects>)

# %% [markdown]
# ## Defnining the CNN model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

import numpy as np
def vgg6(input_shape=(64, 64, 3)):


    model = tf.keras.models.Sequential(name='VGG6')

    model.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=input_shape, name='conv1'))
    model.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu', name='conv2'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.25))

    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', name='conv3'))
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', name='conv4'))
    model.add(tf.keras.layers.BatchNormalization(axis = 3, name = 'bn_2'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(4, 4)))
    model.add(tf.keras.layers.Dropout(0.25))

    ## Fully connected layers
    model.add(tf.keras.layers.Flatten())

    model.add(tf.keras.layers.Dense(256, activation='relu', name='fc_1'))
    model.add(tf.keras.layers.Dropout(0.25))
    
    model.add(tf.keras.layers.Dense(128, activation='relu', name='fc_2'))
    model.add(tf.keras.layers.Dropout(0.25))
    
   
    # output layer
    model.add(tf.keras.layers.Dense(1, name='fc_out'))

    return model

# %%
# snapshot ensemble with custom learning rate schedule
class SnapshotEnsemble(Callback):
	# constructor
	def __init__(self, n_epochs, n_cycles, verbose=0):
		self.epochs = n_epochs
		self.cycles = n_cycles

	# save models at the end of each cycle
	def on_epoch_end(self, epoch, logs={}):
		# check if we can save model
		epochs_per_cycle = floor(self.epochs / self.cycles)
		if epoch != 0 and (epoch + 1) % epochs_per_cycle == 0:
			# save model to file
			filename = "snapshot_model_%d.h5" % int((epoch + 1) / epochs_per_cycle)
			self.model.save(filename)
			print('>saved snapshot %s, epoch %d' % (filename, epoch))



vgg_model = vgg6()
vgg_model.compile(loss='mse', optimizer='adam', metrics=['mse', 'mae'])
n_epochs=30
vgg_model.summary()

from keras.callbacks import Callback
from keras.callbacks import ModelCheckpoint

# checkpoint
# create snapshot ensemble callback
n_cycles = n_epochs / 10
ca = SnapshotEnsemble(n_epochs, n_cycles)

vgg_model_history = vgg_model.fit(images_train, lables_train, 
                                  epochs=n_epochs, batch_size=128, 
                                  validation_data=(images_test, lables_test),
                                  verbose=1, shuffle=True, callbacks=[ca])
# Out:
# Model: "VGG6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 62, 62, 16)        448
# _________________________________________________________________
# conv2 (Conv2D)               (None, 60, 60, 16)        2320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 30, 30, 16)        0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 30, 30, 16)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 28, 28, 32)        4640
# _________________________________________________________________
# conv4 (Conv2D)               (None, 26, 26, 32)        9248
# _________________________________________________________________
# bn_2 (BatchNormalization)    (None, 26, 26, 32)        128
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 6, 6, 32)          0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# fc_1 (Dense)                 (None, 256)               295168
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 256)               0
# _________________________________________________________________
# fc_2 (Dense)                 (None, 128)               32896
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128)               0
# _________________________________________________________________
# fc_out (Dense)               (None, 1)                 129
# =================================================================
# Total params: 344,977
# Trainable params: 344,913
# Non-trainable params: 64
# _________________________________________________________________
# Train on 40316 samples, validate on 963 samples
# Epoch 1/30
# 40316/40316 [==============================] - 5s 114us/sample - loss: 213.4815 - mse: 213.4816 - mae: 10.5872 - val_loss: 699.6284 - val_mse: 699.6284 - val_mae: 24.6195
# Epoch 2/30
# 40316/40316 [==============================] - 4s 102us/sample - loss: 93.8949 - mse: 93.8949 - mae: 7.6465 - val_loss: 439.5095 - val_mse: 439.5094 - val_mae: 18.6255
# Epoch 3/30
# 40316/40316 [==============================] - 4s 102us/sample - loss: 85.7950 - mse: 85.7951 - mae: 7.2893 - val_loss: 303.5908 - val_mse: 303.5908 - val_mae: 15.3453
# Epoch 4/30
# 40316/40316 [==============================] - 4s 102us/sample - loss: 76.1597 - mse: 76.1597 - mae: 6.8643 - val_loss: 451.9722 - val_mse: 451.9722 - val_mae: 19.6369
# Epoch 5/30
# 40316/40316 [==============================] - 4s 106us/sample - loss: 75.5170 - mse: 75.5170 - mae: 6.8351 - val_loss: 84.2521 - val_mse: 84.2521 - val_mae: 7.5872
# Epoch 6/30
# 40316/40316 [==============================] - 4s 99us/sample - loss: 72.6080 - mse: 72.6080 - mae: 6.7107 - val_loss: 96.5837 - val_mse: 96.5837 - val_mae: 8.0077
# Epoch 7/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 66.8379 - mse: 66.8379 - mae: 6.4132 - val_loss: 67.1009 - val_mse: 67.1009 - val_mae: 7.0612
# Epoch 8/30
# 40316/40316 [==============================] - 4s 99us/sample - loss: 64.4642 - mse: 64.4642 - mae: 6.2973 - val_loss: 48.0293 - val_mse: 48.0293 - val_mae: 5.6638
# Epoch 9/30
# 40316/40316 [==============================] - 4s 99us/sample - loss: 62.6019 - mse: 62.6019 - mae: 6.2057 - val_loss: 47.3978 - val_mse: 47.3978 - val_mae: 5.8761
# Epoch 10/30
# 40192/40316 [============================>.] - ETA: 0s - loss: 60.6642 - mse: 60.6642 - mae: 6.1322>saved snapshot snapshot_model_1.h5, epoch 9
# 40316/40316 [==============================] - 4s 101us/sample - loss: 60.7304 - mse: 60.7304 - mae: 6.1345 - val_loss: 33.8694 - val_mse: 33.8694 - val_mae: 4.9151
# Epoch 11/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 60.0929 - mse: 60.0929 - mae: 6.1055 - val_loss: 15.5884 - val_mse: 15.5884 - val_mae: 2.7695
# Epoch 12/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 59.3087 - mse: 59.3087 - mae: 6.0738 - val_loss: 28.6275 - val_mse: 28.6275 - val_mae: 4.3028
# Epoch 13/30
# 40316/40316 [==============================] - 4s 99us/sample - loss: 59.7121 - mse: 59.7121 - mae: 6.0751 - val_loss: 14.4531 - val_mse: 14.4531 - val_mae: 2.7595
# Epoch 14/30
# 40316/40316 [==============================] - 4s 99us/sample - loss: 57.4371 - mse: 57.4371 - mae: 5.9545 - val_loss: 18.8008 - val_mse: 18.8008 - val_mae: 3.2495
# Epoch 15/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 56.9757 - mse: 56.9757 - mae: 5.9241 - val_loss: 11.2525 - val_mse: 11.2525 - val_mae: 2.3920
# Epoch 16/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 55.9737 - mse: 55.9738 - mae: 5.8859 - val_loss: 13.7711 - val_mse: 13.7711 - val_mae: 2.6439
# Epoch 17/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 57.6963 - mse: 57.6963 - mae: 5.9798 - val_loss: 13.5379 - val_mse: 13.5379 - val_mae: 2.7038
# Epoch 18/30
# 40316/40316 [==============================] - 4s 99us/sample - loss: 56.0005 - mse: 56.0005 - mae: 5.8821 - val_loss: 16.1995 - val_mse: 16.1995 - val_mae: 3.1418
# Epoch 19/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 54.4641 - mse: 54.4641 - mae: 5.7905 - val_loss: 25.8064 - val_mse: 25.8064 - val_mae: 4.2782
# Epoch 20/30
# 40192/40316 [============================>.] - ETA: 0s - loss: 53.9174 - mse: 53.9174 - mae: 5.7791>saved snapshot snapshot_model_2.h5, epoch 19
# 40316/40316 [==============================] - 4s 101us/sample - loss: 53.8831 - mse: 53.8831 - mae: 5.7773 - val_loss: 13.2604 - val_mse: 13.2604 - val_mae: 2.6388
# Epoch 21/30
# 40316/40316 [==============================] - 4s 99us/sample - loss: 53.3476 - mse: 53.3476 - mae: 5.7444 - val_loss: 12.2220 - val_mse: 12.2220 - val_mae: 2.5632
# Epoch 22/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 53.9019 - mse: 53.9019 - mae: 5.7829 - val_loss: 10.3437 - val_mse: 10.3437 - val_mae: 2.3477
# Epoch 23/30
# 40316/40316 [==============================] - 4s 103us/sample - loss: 52.4793 - mse: 52.4793 - mae: 5.7038 - val_loss: 16.0545 - val_mse: 16.0545 - val_mae: 3.1055
# Epoch 24/30
# 40316/40316 [==============================] - 4s 103us/sample - loss: 52.4123 - mse: 52.4123 - mae: 5.6922 - val_loss: 21.7280 - val_mse: 21.7280 - val_mae: 3.8385
# Epoch 25/30
# 40316/40316 [==============================] - 4s 101us/sample - loss: 52.3615 - mse: 52.3615 - mae: 5.6930 - val_loss: 14.4946 - val_mse: 14.4946 - val_mae: 2.9512
# Epoch 26/30
# 40316/40316 [==============================] - 4s 99us/sample - loss: 52.6929 - mse: 52.6929 - mae: 5.7049 - val_loss: 17.5178 - val_mse: 17.5178 - val_mae: 3.4234
# Epoch 27/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 52.2290 - mse: 52.2290 - mae: 5.6806 - val_loss: 12.5401 - val_mse: 12.5401 - val_mae: 2.5732
# Epoch 28/30
# 40316/40316 [==============================] - 4s 100us/sample - loss: 50.7855 - mse: 50.7855 - mae: 5.6117 - val_loss: 20.8842 - val_mse: 20.8842 - val_mae: 3.8412
# Epoch 29/30
# 40316/40316 [==============================] - 4s 99us/sample - loss: 49.8156 - mse: 49.8156 - mae: 5.5379 - val_loss: 9.8130 - val_mse: 9.8130 - val_mae: 2.2242
# Epoch 30/30
# 39680/40316 [============================>.] - ETA: 0s - loss: 51.0981 - mse: 51.0981 - mae: 5.6356>saved snapshot snapshot_model_3.h5, epoch 29
# 40316/40316 [==============================] - 4s 101us/sample - loss: 51.0806 - mse: 51.0806 - mae: 5.6340 - val_loss: 10.2077 - val_mse: 10.2077 - val_mae: 2.3807

# %%
# for key in vgg_model.history.history:
#   print key

# %%
def plot_model_history(history):
    '''Plot the training and validation history for a TensorFlow network'''

    # Extract loss and accuracy
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    acc = history.history['mse']
    val_acc = history.history['val_mse']
    
    fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(10,5))
    ax[0].plot(np.arange(n_epochs), loss, label='Training')
    ax[0].plot(np.arange(n_epochs), val_loss, label='Validation')
    ax[0].set_title('Mean Square Error')
    ax[0].legend()
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Loss')

    ax[1].plot(np.arange(n_epochs), acc, label='Training')
    ax[1].plot(np.arange(n_epochs), val_acc, label='Validation')
    ax[1].set_title('Mean Absolute Error Curves')
    ax[1].legend()
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Mean Absolute Error')
    
# plot the training history
# for key in vgg_model.history.history:
#   print key

plot_model_history(vgg_model.history)

# %% [markdown]
# ## Saving the model
# Storing the model weight numbers

# %%
vgg_model.save("/content/drive/My Drive/CNN_inc_VGG6_regr.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## Evaluationg the model

# %%
inc_p = vgg_model.predict(images_test)
inc_m = lables_test


N = images_test.shape[0]
inc_p = inc_p.reshape(N)

# %%
images_test.shape
# Out:
# (963, 64, 64, 3)

# %% [markdown]
# ## An example of evaluated inclination

# %%
i = 750

print "Predicted: ", inc_p[i]
print "Measured: ", inc_m[i]
plt.imshow(images_test[i])
# Out:
# Predicted:  78.69161
# Measured:  77

# %% [markdown]
# ## Predictions vs. Actual measurments
# (Test sample)

# %%
fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(10,5)) 

d = inc_m-inc_p

m, b = np.polyfit(inc_m, d, 1)
x = np.linspace(50,90,20)
y  = m*x+b

ax[0].plot(inc_m, d, 'b.')
ax[0].plot([50,90],[0,0], 'k:')
ax[0].plot(x, y, 'r-')
ax[0].set_xlim(48,92)
ax[0].set_ylim(-10,30)
ax[0].set_title('Raw Prediction', fontsize=16)
ax[0].set_xlabel(r'$i_m$'+'  (measured inclination)', fontsize=14)
ax[0].set_ylabel(r'$\Delta i = i_m-i_p$', fontsize=14)

print "Raw RMS: ", np.sqrt(np.mean((d)**2))


d_ = inc_m-(inc_p+b)/(1.-m)
ax[1].plot(inc_m, d_, 'g.')
ax[1].plot([50,90],[0,0], 'k:')
ax[1].set_xlim(48,92)
ax[1].set_ylim(-10,30)

print "Adjusted RMS: ", np.sqrt(np.mean((d_)**2))
ax[1].set_title('Adjusted Prediction', fontsize=16)
ax[1].set_xlabel(r'$i_m$'+'  (measured inclination)', fontsize=14)
ax[1].set_ylabel(r'$\Delta i = i_m-i_{pc}$', fontsize=14)

plt.subplots_adjust( wspace=0.3)
# Out:
# Raw RMS:  3.194949041744324
# Adjusted RMS:  3.1757139735986875

# %%
fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(10,5)) 

ax[0].plot(inc_m, inc_p, 'b.')
ax[0].plot([48,92],[48,92], 'k:')
ax[0].set_xlim(48,92)
ax[0].set_ylim(48,92)
ax[0].set_title('Raw', fontsize=16)
ax[0].set_xlabel(r'$i_m$'+'  (measured inclination)', fontsize=14)
ax[0].set_ylabel(r'$i_p$'+'  (predicted inclination)', fontsize=14)

ax[1].plot(inc_m, (inc_p+b)/(1.-m), 'g.')
ax[1].plot([48,92],[48,92], 'k:')
ax[1].set_xlim(48,92)
ax[1].set_ylim(48,92)
ax[1].plot([48,92],[90,90], 'r:')
ax[1].set_title('Adjusted', fontsize=16)
ax[1].set_xlabel(r'$i_m$'+'  (measured inclination)', fontsize=14)
ax[1].set_ylabel(r'$i_{pc}$'+'  (adjusted inclination)', fontsize=14)

plt.subplots_adjust( wspace=0.3)
